# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []
# Identify latitude and longitude combination the nearest cities.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# If city is not present ad to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count 
len(cities)
# Out:
# 746

# %%
# Import the requests.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | san vicente
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | joplin
# Processing Record 7 of Set 1 | ambilobe
# Processing Record 8 of Set 1 | sampit
# Processing Record 9 of Set 1 | savannah bight
# Processing Record 10 of Set 1 | oranjemund
# Processing Record 11 of Set 1 | namatanai
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 1 | qinzhou
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | ijuin
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | te anau
# Processing Record 27 of Set 1 | san cristobal
# Processing Record 28 of Set 1 | pachmarhi
# Processing Record 29 of Set 1 | ilhabela
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | aketi
# Processing Record 32 of Set 1 | santa paula
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | wadi musa
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | elat
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | limon
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | sao jose da coroa grande
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | alice springs
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | prabumulih
# Processing Record 4 of Set 2 | taree
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | valavanur
# Processing Record 7 of Set 2 | goure
# Processing Record 8 of Set 2 | mandan
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | sihor
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | houston
# Processing Record 13 of Set 2 | swellendam
# Processing Record 14 of Set 2 | jian
# Processing Record 15 of Set 2 | hualmay
# Processing Record 16 of Set 2 | chernyshevskiy
# Processing Record 17 of Set 2 | sayyan
# Processing Record 18 of Set 2 | el centro
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | husavik
# Processing Record 21 of Set 2 | valday
# Processing Record 22 of Set 2 | waddan
# Processing Record 23 of Set 2 | havre-saint-pierre
# Processing Record 24 of Set 2 | roald
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | vestmannaeyjar
# Processing Record 28 of Set 2 | pacific grove
# Processing Record 29 of Set 2 | hefei
# Processing Record 30 of Set 2 | byron bay
# Processing Record 31 of Set 2 | oussouye
# Processing Record 32 of Set 2 | birchis
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | katsuura
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | acapulco
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | alizai
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | yaan
# Processing Record 42 of Set 2 | sorland
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | pontianak
# Processing Record 46 of Set 2 | olinda
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 2 | dhadar
# Processing Record 50 of Set 2 | tautira
# Processing Record 1 of Set 3 | sao joao da barra
# Processing Record 2 of Set 3 | batasan
# Processing Record 3 of Set 3 | ushuaia
# Processing Record 4 of Set 3 | tura
# Processing Record 5 of Set 3 | mount gambier
# Processing Record 6 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | selaphum
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | tabas
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | boa vista
# Processing Record 14 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 3 | hobart
# Processing Record 16 of Set 3 | alexandria
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | malkangiri
# Processing Record 19 of Set 3 | kambia
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | aksha
# Processing Record 25 of Set 3 | matara
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | iquique
# Processing Record 28 of Set 3 | kemise
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | mangan
# Processing Record 31 of Set 3 | sinnamary
# Processing Record 32 of Set 3 | hohhot
# Processing Record 33 of Set 3 | camopi
# Processing Record 34 of Set 3 | bowen
# Processing Record 35 of Set 3 | aitape
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | diamantino
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | tezu
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | klyuchi
# Processing Record 43 of Set 3 | nchelenge
# Processing Record 44 of Set 3 | camana
# Processing Record 45 of Set 3 | san quintin
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | celestun
# Processing Record 48 of Set 3 | the valley
# Processing Record 49 of Set 3 | lashio
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | la mirada
# Processing Record 2 of Set 4 | zhicheng
# Processing Record 3 of Set 4 | micheweni
# Processing Record 4 of Set 4 | visnes
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | ucluelet
# Processing Record 7 of Set 4 | shakawe
# Processing Record 8 of Set 4 | hojai
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | los llanos de aridane
# Processing Record 11 of Set 4 | honningsvag
# Processing Record 12 of Set 4 | doctor juan leon mallorquin
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | vostok
# Processing Record 15 of Set 4 | bemidji
# Processing Record 16 of Set 4 | ixtapa
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | susanino
# Processing Record 19 of Set 4 | jacareacanga
# Processing Record 20 of Set 4 | sarab
# Processing Record 21 of Set 4 | gigmoto
# Processing Record 22 of Set 4 | kavieng
# Processing Record 23 of Set 4 | seabra
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | broadstairs
# Processing Record 26 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | chastoozerye
# City not found. Skipping...
# Processing Record 28 of Set 4 | ancud
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | akhalgori
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | tretten
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | qaqortoq
# Processing Record 35 of Set 4 | khao wong
# Processing Record 36 of Set 4 | kraskino
# Processing Record 37 of Set 4 | manaure
# Processing Record 38 of Set 4 | jamestown
# Processing Record 39 of Set 4 | mahebourg
# Processing Record 40 of Set 4 | iranshahr
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | lieksa
# Processing Record 43 of Set 4 | vrnograc
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | nizhniy tsasuchey
# Processing Record 46 of Set 4 | isilkul
# Processing Record 47 of Set 4 | tilichiki
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | guayaramerin
# Processing Record 50 of Set 4 | turhal
# Processing Record 1 of Set 5 | milford
# Processing Record 2 of Set 5 | beidao
# Processing Record 3 of Set 5 | ola
# Processing Record 4 of Set 5 | romny
# Processing Record 5 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | babstovo
# Processing Record 9 of Set 5 | baruun-urt
# Processing Record 10 of Set 5 | kabinda
# Processing Record 11 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 12 of Set 5 | maumere
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | san luis
# Processing Record 15 of Set 5 | kathu
# Processing Record 16 of Set 5 | bismarck
# Processing Record 17 of Set 5 | champerico
# Processing Record 18 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | areado
# Processing Record 21 of Set 5 | flinders
# Processing Record 22 of Set 5 | dwarka
# Processing Record 23 of Set 5 | saint george
# Processing Record 24 of Set 5 | danjiangkou
# Processing Record 25 of Set 5 | coquimbo
# Processing Record 26 of Set 5 | maracacume
# Processing Record 27 of Set 5 | la sarre
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | tatarsk
# Processing Record 30 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 5 | cacule
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | sinop
# Processing Record 34 of Set 5 | uribia
# Processing Record 35 of Set 5 | roma
# Processing Record 36 of Set 5 | puerto baquerizo moreno
# Processing Record 37 of Set 5 | sal rei
# Processing Record 38 of Set 5 | upernavik
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | port lincoln
# Processing Record 41 of Set 5 | kloulklubed
# Processing Record 42 of Set 5 | murgab
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | blackwater
# Processing Record 45 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 5 | caraquet
# Processing Record 47 of Set 5 | hede
# Processing Record 48 of Set 5 | ballina
# Processing Record 49 of Set 5 | buala
# Processing Record 50 of Set 5 | nacala
# Processing Record 1 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 6 | port hedland
# Processing Record 3 of Set 6 | marzuq
# Processing Record 4 of Set 6 | shalinskoye
# Processing Record 5 of Set 6 | sarai
# Processing Record 6 of Set 6 | ormara
# Processing Record 7 of Set 6 | hay river
# Processing Record 8 of Set 6 | marathon
# Processing Record 9 of Set 6 | porto novo
# Processing Record 10 of Set 6 | cayenne
# Processing Record 11 of Set 6 | bonthe
# Processing Record 12 of Set 6 | impfondo
# Processing Record 13 of Set 6 | nikolskoye
# Processing Record 14 of Set 6 | nyimba
# Processing Record 15 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 6 | basoko
# Processing Record 17 of Set 6 | shalya
# Processing Record 18 of Set 6 | imbituba
# Processing Record 19 of Set 6 | dingle
# Processing Record 20 of Set 6 | arlit
# Processing Record 21 of Set 6 | wanning
# Processing Record 22 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 6 | kulhudhuffushi
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | verkhnyaya sinyachikha
# Processing Record 26 of Set 6 | gunjur
# Processing Record 27 of Set 6 | cairns
# Processing Record 28 of Set 6 | aykhal
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | stornoway
# Processing Record 31 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 6 | mount vernon
# Processing Record 33 of Set 6 | palu
# Processing Record 34 of Set 6 | bethel
# Processing Record 35 of Set 6 | goderich
# Processing Record 36 of Set 6 | vila do maio
# Processing Record 37 of Set 6 | walvis bay
# Processing Record 38 of Set 6 | nome
# Processing Record 39 of Set 6 | freeport
# Processing Record 40 of Set 6 | yarmolyntsi
# Processing Record 41 of Set 6 | odate
# Processing Record 42 of Set 6 | eucaliptus
# Processing Record 43 of Set 6 | shimoda
# Processing Record 44 of Set 6 | svetlogorsk
# Processing Record 45 of Set 6 | belis
# Processing Record 46 of Set 6 | rockingham
# Processing Record 47 of Set 6 | kalmunai
# Processing Record 48 of Set 6 | tampere
# Processing Record 49 of Set 6 | tutoia
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | aksu
# Processing Record 2 of Set 7 | moussoro
# Processing Record 3 of Set 7 | faanui
# Processing Record 4 of Set 7 | beyneu
# Processing Record 5 of Set 7 | quatre cocos
# Processing Record 6 of Set 7 | san francisco
# Processing Record 7 of Set 7 | port hardy
# Processing Record 8 of Set 7 | mareeba
# Processing Record 9 of Set 7 | emerald
# Processing Record 10 of Set 7 | balkanabat
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | popondetta
# Processing Record 13 of Set 7 | sao filipe
# Processing Record 14 of Set 7 | parambu
# Processing Record 15 of Set 7 | aleksandrovsk-sakhalinskiy
# Processing Record 16 of Set 7 | kharan
# Processing Record 17 of Set 7 | ketchikan
# Processing Record 18 of Set 7 | ribeira grande
# Processing Record 19 of Set 7 | knyaze-volkonskoye
# Processing Record 20 of Set 7 | port-gentil
# Processing Record 21 of Set 7 | kieta
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | samarai
# Processing Record 24 of Set 7 | tigil
# Processing Record 25 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 7 | luanda
# Processing Record 27 of Set 7 | yinchuan
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | inhambane
# Processing Record 30 of Set 7 | yining
# Processing Record 31 of Set 7 | lebu
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | kochi
# Processing Record 34 of Set 7 | shiojiri
# Processing Record 35 of Set 7 | shumskiy
# Processing Record 36 of Set 7 | maroantsetra
# Processing Record 37 of Set 7 | assiniboia
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | waycross
# Processing Record 40 of Set 7 | goya
# Processing Record 41 of Set 7 | olafsvik
# Processing Record 42 of Set 7 | vanimo
# Processing Record 43 of Set 7 | harrai
# Processing Record 44 of Set 7 | wilmington island
# Processing Record 45 of Set 7 | nanortalik
# Processing Record 46 of Set 7 | sirtich
# Processing Record 47 of Set 7 | nuuk
# Processing Record 48 of Set 7 | birjand
# Processing Record 49 of Set 7 | bingol
# Processing Record 50 of Set 7 | fort nelson
# Processing Record 1 of Set 8 | puerto leguizamo
# Processing Record 2 of Set 8 | tapes
# Processing Record 3 of Set 8 | jinchang
# Processing Record 4 of Set 8 | saint-joseph
# Processing Record 5 of Set 8 | tres picos
# Processing Record 6 of Set 8 | mandla
# Processing Record 7 of Set 8 | lexington
# Processing Record 8 of Set 8 | diego de almagro
# Processing Record 9 of Set 8 | aleksandrov gay
# Processing Record 10 of Set 8 | visakhapatnam
# Processing Record 11 of Set 8 | saint anthony
# Processing Record 12 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 13 of Set 8 | klaksvik
# Processing Record 14 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 8 | alghero
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | armidale
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | flin flon
# Processing Record 20 of Set 8 | strezhevoy
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | kahului
# Processing Record 23 of Set 8 | yumen
# Processing Record 24 of Set 8 | minot
# Processing Record 25 of Set 8 | eenhana
# Processing Record 26 of Set 8 | victoria
# Processing Record 27 of Set 8 | bonoua
# Processing Record 28 of Set 8 | callaway
# Processing Record 29 of Set 8 | port pirie
# Processing Record 30 of Set 8 | noumea
# Processing Record 31 of Set 8 | krasnoye
# Processing Record 32 of Set 8 | esso
# Processing Record 33 of Set 8 | ryazan
# Processing Record 34 of Set 8 | lavumisa
# Processing Record 35 of Set 8 | saldanha
# Processing Record 36 of Set 8 | cooma
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | santa maria
# Processing Record 40 of Set 8 | tiarei
# Processing Record 41 of Set 8 | kawalu
# Processing Record 42 of Set 8 | bedong
# Processing Record 43 of Set 8 | dzilam gonzalez
# Processing Record 44 of Set 8 | mehamn
# Processing Record 45 of Set 8 | atar
# Processing Record 46 of Set 8 | ilabaya
# Processing Record 47 of Set 8 | talcahuano
# Processing Record 48 of Set 8 | sfantu gheorghe
# Processing Record 49 of Set 8 | bogorodskoye
# Processing Record 50 of Set 8 | batagay
# Processing Record 1 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | marystown
# Processing Record 3 of Set 9 | denpasar
# Processing Record 4 of Set 9 | port moresby
# Processing Record 5 of Set 9 | hokitika
# Processing Record 6 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 9 | dikson
# Processing Record 8 of Set 9 | sovetskiy
# Processing Record 9 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 9 | novoagansk
# Processing Record 11 of Set 9 | kirakira
# Processing Record 12 of Set 9 | aripuana
# Processing Record 13 of Set 9 | alugan
# Processing Record 14 of Set 9 | nizwa
# Processing Record 15 of Set 9 | balakhninskiy
# Processing Record 16 of Set 9 | muros
# Processing Record 17 of Set 9 | san juan del sur
# Processing Record 18 of Set 9 | bengkulu
# Processing Record 19 of Set 9 | mao
# Processing Record 20 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 9 | mezen
# Processing Record 22 of Set 9 | novochernorechenskiy
# Processing Record 23 of Set 9 | morehead
# Processing Record 24 of Set 9 | hofn
# Processing Record 25 of Set 9 | yerbogachen
# Processing Record 26 of Set 9 | mwinilunga
# Processing Record 27 of Set 9 | hutchinson
# Processing Record 28 of Set 9 | poum
# Processing Record 29 of Set 9 | grand gaube
# Processing Record 30 of Set 9 | korem
# Processing Record 31 of Set 9 | masvingo
# Processing Record 32 of Set 9 | gubbio
# Processing Record 33 of Set 9 | brandon
# Processing Record 34 of Set 9 | hasanabad
# Processing Record 35 of Set 9 | ranikhet
# Processing Record 36 of Set 9 | ormoz
# Processing Record 37 of Set 9 | isangel
# Processing Record 38 of Set 9 | yar-sale
# Processing Record 39 of Set 9 | taoudenni
# Processing Record 40 of Set 9 | pajan
# Processing Record 41 of Set 9 | tarbagatay
# Processing Record 42 of Set 9 | verkhnetulomskiy
# Processing Record 43 of Set 9 | junagarh
# Processing Record 44 of Set 9 | turukhansk
# Processing Record 45 of Set 9 | margate
# Processing Record 46 of Set 9 | kudahuvadhoo
# Processing Record 47 of Set 9 | vila velha
# Processing Record 48 of Set 9 | monrovia
# Processing Record 49 of Set 9 | fenoarivo atsinanana
# Processing Record 50 of Set 9 | palauig
# Processing Record 1 of Set 10 | kandrian
# Processing Record 2 of Set 10 | huarmey
# Processing Record 3 of Set 10 | tahoua
# Processing Record 4 of Set 10 | la orilla
# Processing Record 5 of Set 10 | sur
# Processing Record 6 of Set 10 | zinder
# Processing Record 7 of Set 10 | ha tinh
# Processing Record 8 of Set 10 | rio grande
# Processing Record 9 of Set 10 | port macquarie
# Processing Record 10 of Set 10 | campo grande
# Processing Record 11 of Set 10 | tromso
# Processing Record 12 of Set 10 | issia
# Processing Record 13 of Set 10 | oloron-sainte-marie
# Processing Record 14 of Set 10 | san andres
# Processing Record 15 of Set 10 | kaoma
# Processing Record 16 of Set 10 | dhidhdhoo
# Processing Record 17 of Set 10 | kuusamo
# Processing Record 18 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 10 | arman
# Processing Record 20 of Set 10 | abay
# Processing Record 21 of Set 10 | mayo
# Processing Record 22 of Set 10 | aklavik
# Processing Record 23 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 10 | osoyoos
# Processing Record 25 of Set 10 | kuah
# Processing Record 26 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 10 | maracaibo
# Processing Record 28 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 10 | namibe
# Processing Record 30 of Set 10 | airai
# Processing Record 31 of Set 10 | sterling
# Processing Record 32 of Set 10 | burgos
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | churachandpur
# Processing Record 35 of Set 10 | bouna
# Processing Record 36 of Set 10 | soe
# Processing Record 37 of Set 10 | moroni
# Processing Record 38 of Set 10 | pucallpa
# Processing Record 39 of Set 10 | sitka
# Processing Record 40 of Set 10 | mendoza
# Processing Record 41 of Set 10 | yulara
# Processing Record 42 of Set 10 | ust-nera
# Processing Record 43 of Set 10 | shinpokh
# Processing Record 44 of Set 10 | otane
# Processing Record 45 of Set 10 | bosaso
# Processing Record 46 of Set 10 | sorong
# Processing Record 47 of Set 10 | jalu
# Processing Record 48 of Set 10 | soyo
# Processing Record 49 of Set 10 | karratha
# Processing Record 50 of Set 10 | slyudyanka
# Processing Record 1 of Set 11 | sabang
# Processing Record 2 of Set 11 | himora
# City not found. Skipping...
# Processing Record 3 of Set 11 | aviles
# Processing Record 4 of Set 11 | rawson
# Processing Record 5 of Set 11 | oruro
# Processing Record 6 of Set 11 | ginir
# Processing Record 7 of Set 11 | progreso
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | lodja
# Processing Record 10 of Set 11 | dinguiraye
# Processing Record 11 of Set 11 | trairi
# Processing Record 12 of Set 11 | bull savanna
# Processing Record 13 of Set 11 | dillon
# Processing Record 14 of Set 11 | honolulu
# Processing Record 15 of Set 11 | shambu
# Processing Record 16 of Set 11 | ilulissat
# Processing Record 17 of Set 11 | severo-yeniseyskiy
# Processing Record 18 of Set 11 | chengdu
# Processing Record 19 of Set 11 | san rafael
# Processing Record 20 of Set 11 | miraflores
# Processing Record 21 of Set 11 | dzaoudzi
# Processing Record 22 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 11 | nanakuli
# Processing Record 24 of Set 11 | general pico
# Processing Record 25 of Set 11 | carballo
# Processing Record 26 of Set 11 | pyaozerskiy
# Processing Record 27 of Set 11 | mitu
# Processing Record 28 of Set 11 | meulaboh
# Processing Record 29 of Set 11 | cabiraoan
# Processing Record 30 of Set 11 | puerto carreno
# Processing Record 31 of Set 11 | kapit
# Processing Record 32 of Set 11 | pontes e lacerda
# Processing Record 33 of Set 11 | banda aceh
# Processing Record 34 of Set 11 | broome
# Processing Record 35 of Set 11 | zabid
# Processing Record 36 of Set 11 | reconquista
# Processing Record 37 of Set 11 | canela
# Processing Record 38 of Set 11 | half moon bay
# Processing Record 39 of Set 11 | vyazemskiy
# Processing Record 40 of Set 11 | skjervoy
# Processing Record 41 of Set 11 | wageningen
# Processing Record 42 of Set 11 | zhigansk
# Processing Record 43 of Set 11 | south shields
# Processing Record 44 of Set 11 | glyadyanskoye
# Processing Record 45 of Set 11 | salisbury
# Processing Record 46 of Set 11 | stephenville
# Processing Record 47 of Set 11 | coruripe
# Processing Record 48 of Set 11 | northam
# Processing Record 49 of Set 11 | weihai
# Processing Record 50 of Set 11 | rundu
# Processing Record 1 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 12 | xingyi
# Processing Record 3 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 12 | saumur
# Processing Record 5 of Set 12 | mount isa
# Processing Record 6 of Set 12 | rizhao
# Processing Record 7 of Set 12 | satun
# Processing Record 8 of Set 12 | portsmouth
# Processing Record 9 of Set 12 | baracoa
# Processing Record 10 of Set 12 | petauke
# Processing Record 11 of Set 12 | la ronge
# Processing Record 12 of Set 12 | hovd
# Processing Record 13 of Set 12 | bayan
# Processing Record 14 of Set 12 | berlevag
# Processing Record 15 of Set 12 | khilok
# Processing Record 16 of Set 12 | sairang
# Processing Record 17 of Set 12 | atlantic beach
# Processing Record 18 of Set 12 | sokoto
# Processing Record 19 of Set 12 | merke
# Processing Record 20 of Set 12 | abha
# Processing Record 21 of Set 12 | rafsanjan
# Processing Record 22 of Set 12 | lima
# Processing Record 23 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 12 | tyup
# Processing Record 25 of Set 12 | warud
# Processing Record 26 of Set 12 | katha
# City not found. Skipping...
# Processing Record 27 of Set 12 | chabahar
# Processing Record 28 of Set 12 | reefton
# City not found. Skipping...
# Processing Record 29 of Set 12 | tabou
# Processing Record 30 of Set 12 | knysna
# Processing Record 31 of Set 12 | dubuque
# Processing Record 32 of Set 12 | evensk
# Processing Record 33 of Set 12 | san patricio
# Processing Record 34 of Set 12 | komsomolskiy
# Processing Record 35 of Set 12 | bonfim
# Processing Record 36 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 12 | le port
# Processing Record 38 of Set 12 | lakatoro
# Processing Record 39 of Set 12 | kamien pomorski
# Processing Record 40 of Set 12 | sola
# Processing Record 41 of Set 12 | monte carmelo
# Processing Record 42 of Set 12 | mangit
# Processing Record 43 of Set 12 | mirnyy
# Processing Record 44 of Set 12 | emba
# Processing Record 45 of Set 12 | shingu
# Processing Record 46 of Set 12 | iqaluit
# Processing Record 47 of Set 12 | pala
# Processing Record 48 of Set 12 | gondanglegi
# Processing Record 49 of Set 12 | shu
# Processing Record 50 of Set 12 | richards bay
# Processing Record 1 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 2 of Set 13 | santa maria del oro
# Processing Record 3 of Set 13 | zhanaozen
# Processing Record 4 of Set 13 | ludvika
# Processing Record 5 of Set 13 | kirkland lake
# Processing Record 6 of Set 13 | clyde river
# Processing Record 7 of Set 13 | mamallapuram
# Processing Record 8 of Set 13 | krutinka
# Processing Record 9 of Set 13 | port blair
# Processing Record 10 of Set 13 | hue
# Processing Record 11 of Set 13 | sisimiut
# Processing Record 12 of Set 13 | la paz
# Processing Record 13 of Set 13 | lloydminster
# Processing Record 14 of Set 13 | gamba
# Processing Record 15 of Set 13 | manassas
# Processing Record 16 of Set 13 | paris
# Processing Record 17 of Set 13 | morki
# Processing Record 18 of Set 13 | terrace
# Processing Record 19 of Set 13 | puerto penasco
# Processing Record 20 of Set 13 | honiara
# Processing Record 21 of Set 13 | itarema
# Processing Record 22 of Set 13 | pacifica
# Processing Record 23 of Set 13 | portland
# Processing Record 24 of Set 13 | kununurra
# Processing Record 25 of Set 13 | sinegorskiy
# Processing Record 26 of Set 13 | calvinia
# Processing Record 27 of Set 13 | henties bay
# Processing Record 28 of Set 13 | eureka
# Processing Record 29 of Set 13 | takoradi
# Processing Record 30 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 13 | bideford
# Processing Record 32 of Set 13 | mazagao
# Processing Record 33 of Set 13 | qasigiannguit
# Processing Record 34 of Set 13 | asau
# Processing Record 35 of Set 13 | duku
# Processing Record 36 of Set 13 | san martin
# Processing Record 37 of Set 13 | mokrous
# Processing Record 38 of Set 13 | brae
# Processing Record 39 of Set 13 | vilyuysk
# Processing Record 40 of Set 13 | niksic
# Processing Record 41 of Set 13 | cap malheureux
# Processing Record 42 of Set 13 | sarana
# Processing Record 43 of Set 13 | san carlos de bariloche
# Processing Record 44 of Set 13 | healdsburg
# Processing Record 45 of Set 13 | numan
# Processing Record 46 of Set 13 | ende
# Processing Record 47 of Set 13 | sandwick
# Processing Record 48 of Set 13 | gizo
# Processing Record 49 of Set 13 | coihaique
# Processing Record 50 of Set 13 | tambura
# Processing Record 1 of Set 14 | bontang
# Processing Record 2 of Set 14 | rantepao
# Processing Record 3 of Set 14 | constitucion
# Processing Record 4 of Set 14 | belmonte
# Processing Record 5 of Set 14 | kabanjahe
# Processing Record 6 of Set 14 | guilin
# Processing Record 7 of Set 14 | sasciori
# Processing Record 8 of Set 14 | pangnirtung
# Processing Record 9 of Set 14 | hamilton
# Processing Record 10 of Set 14 | tateyama
# Processing Record 11 of Set 14 | salalah
# Processing Record 12 of Set 14 | tarakan
# Processing Record 13 of Set 14 | cabimas
# Processing Record 14 of Set 14 | huilong
# Processing Record 15 of Set 14 | saint-pierre
# Processing Record 16 of Set 14 | saint paul
# Processing Record 17 of Set 14 | krasnoselkup
# Processing Record 18 of Set 14 | norton
# Processing Record 19 of Set 14 | hwange
# Processing Record 20 of Set 14 | kabare
# Processing Record 21 of Set 14 | gravdal
# Processing Record 22 of Set 14 | piacabucu
# Processing Record 23 of Set 14 | vila franca do campo
# Processing Record 24 of Set 14 | okhotsk
# Processing Record 25 of Set 14 | witbank
# Processing Record 26 of Set 14 | alta floresta
# Processing Record 27 of Set 14 | vestmanna
# Processing Record 28 of Set 14 | chicama
# Processing Record 29 of Set 14 | chifeng
# Processing Record 30 of Set 14 | huanren
# Processing Record 31 of Set 14 | yefimovskiy
# City not found. Skipping...
# Processing Record 32 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 14 | acari
# Processing Record 34 of Set 14 | tres passos
# Processing Record 35 of Set 14 | yamethin
# Processing Record 36 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 14 | almaty
# Processing Record 38 of Set 14 | calasuche
# City not found. Skipping...
# Processing Record 39 of Set 14 | inta
# Processing Record 40 of Set 14 | chino valley
# Processing Record 41 of Set 14 | desaguadero
# Processing Record 42 of Set 14 | lufkin
# Processing Record 43 of Set 14 | dayong
# Processing Record 44 of Set 14 | darnah
# Processing Record 45 of Set 14 | burica
# City not found. Skipping...
# Processing Record 46 of Set 14 | turbat
# Processing Record 47 of Set 14 | adrar
# Processing Record 48 of Set 14 | balykshi
# Processing Record 49 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 14 | comodoro rivadavia
# Processing Record 1 of Set 15 | dong hoi
# Processing Record 2 of Set 15 | quelimane
# Processing Record 3 of Set 15 | tanout
# Processing Record 4 of Set 15 | buerarema
# Processing Record 5 of Set 15 | lata
# Processing Record 6 of Set 15 | belaya gora
# Processing Record 7 of Set 15 | tommot
# Processing Record 8 of Set 15 | saint-augustin
# Processing Record 9 of Set 15 | mackay
# Processing Record 10 of Set 15 | garden city
# Processing Record 11 of Set 15 | talakan
# Processing Record 12 of Set 15 | humberto de campos
# Processing Record 13 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 15 | amga
# Processing Record 15 of Set 15 | verkhniye tatyshly
# Processing Record 16 of Set 15 | manavalakurichi
# Processing Record 17 of Set 15 | domoni
# Processing Record 18 of Set 15 | gazojak
# Processing Record 19 of Set 15 | verkhnyaya toyma
# Processing Record 20 of Set 15 | itoman
# Processing Record 21 of Set 15 | zhezkazgan
# Processing Record 22 of Set 15 | abu kamal
# Processing Record 23 of Set 15 | wuda
# Processing Record 24 of Set 15 | halvad
# Processing Record 25 of Set 15 | xixiang
# Processing Record 26 of Set 15 | pandamatenga
# Processing Record 27 of Set 15 | paraiso
# Processing Record 28 of Set 15 | kuryk
# Processing Record 29 of Set 15 | sinazongwe
# Processing Record 30 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 15 | rudnogorsk
# Processing Record 32 of Set 15 | leningradskiy
# Processing Record 33 of Set 15 | aksay
# Processing Record 34 of Set 15 | barranca
# Processing Record 35 of Set 15 | thanh hoa
# Processing Record 36 of Set 15 | nizhneangarsk
# Processing Record 37 of Set 15 | oxford
# Processing Record 38 of Set 15 | vakhrushev
# Processing Record 39 of Set 15 | makakilo city
# Processing Record 40 of Set 15 | bukachacha
# Processing Record 41 of Set 15 | daru
# Processing Record 42 of Set 15 | ngaoundere
# Processing Record 43 of Set 15 | kuanhsi
# City not found. Skipping...
# Processing Record 44 of Set 15 | aguas vermelhas
# Processing Record 45 of Set 15 | mandera
# Processing Record 46 of Set 15 | abu samrah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Keningau      MY   5.3378  116.1602     72.05        99
# 1         Esperance      AU -33.8667  121.9000     57.11        87
# 2          Khatanga      RU  71.9667  102.5000     22.37        97
# 3          Ust-Nera      RU  64.5667  143.2000      4.48        95
# 4           Hualmay      PE -11.0964  -77.6139     69.58        72
# 5           Ushuaia      AR -54.8000  -68.3000     49.75        52
# 6            Castro      BR -24.7911  -50.0119     59.68        76
# 7           Malanje      AO  -9.5402   16.3410     66.09        91
# 8  Pontes E Lacerda      BR -15.2261  -59.3353     96.84        25
# 9          Hermanus      ZA -34.4187   19.2345     67.89        87
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.60     overcast clouds
# 1          19       15.30          few clouds
# 2         100        4.27          light snow
# 3         100        2.26     overcast clouds
# 4          44       11.32    scattered clouds
# 5          99        5.14     overcast clouds
# 6          96        7.56     overcast clouds
# 7          79        2.59          light rain
# 8          11        2.73          few clouds
# 9          65       11.39       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
